# %%
import

# %%
import pandas as pd
dataset=pd.read_csv("/content/Tips.csv")
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
dataset.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
dataset[2:68]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# ..         ...   ...     ...    ...  ...     ...   ...
# 63       18.29  3.76    Male    Yes  Sat  Dinner     4
# 64       17.59  2.64    Male     No  Sat  Dinner     3
# 65       20.08  3.15    Male     No  Sat  Dinner     3
# 66       16.45  2.47  Female     No  Sat  Dinner     2
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1
#
# [66 rows x 7 columns]

# %%
dataset[45:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 45        18.29  3.00    Male     No   Sun  Dinner     2
# 46        22.23  5.00    Male     No   Sun  Dinner     2
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 48        28.55  2.05    Male     No   Sun  Dinner     3
# 49        18.04  3.00    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [199 rows x 7 columns]

# %%
dataset.shape
# Out:
# (244, 7)

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
dataset.index #index of tips datafreame
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
dataset.dtypes.value_counts() #how many variables of each datatype in the dataset
# Out:
# object     4
# float64    2
# int64      1
# Name: count, dtype: int64

# %%
dataset.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
dataset['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
dataset.sort_values(by='size') #sort dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 0         16.99  1.01  Female     No   Sun  Dinner     2

# %%
dataset['sex'].value_counts() #count the male and female person from tae datset
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
dataset['day'].value_counts() #count the day from tae datset
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
dataset['smoker'].describe()
# Out:
# count     244
# unique      2
# top        No
# freq      151
# Name: smoker, dtype: object

# %%
dataset['sex'].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
dataset['sex'].value_counts()['Male']
# Out:
# 157

# %%
male_count=dataset['sex'].value_counts().get('Male')
print(f"Male:{male_count}")
# Out:
# Male:157
